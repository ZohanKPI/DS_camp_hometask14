# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering, DBSCAN, KMeans
import warnings
warnings.filterwarnings('default')

X, y = make_blobs(n_samples = 500, n_features = 2, centers = 5, 
                           cluster_std = 0., random_state = 0)
colors = np.array([plt.cm.Spectral(val)
          for val in np.linspace(0, 1, len(set(y)))])
plt.figure(figsize=(8,6))

plt.scatter(X[:,0], X[:,1], c= colors[y], s= 20)

# %%
agg_clustering_complete = AgglomerativeClustering(n_clusters=5, linkage='complete')
labels_complete = agg_clustering_complete.fit_predict(X)

agg_clustering_single = AgglomerativeClustering(n_clusters=5, linkage='single')
labels_single = agg_clustering_single.fit_predict(X)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=colors[labels_complete], s=20)
plt.title("Agglomerative Clustering (Complete Linkage)")

plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=colors[labels_single], s=20)
plt.title("Agglomerative Clustering (Single Linkage)")

plt.show()

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels_dbscan = dbscan.fit_predict(X)

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=colors[labels_dbscan], s=20)
plt.title("DBSCAN Clustering")
plt.show()

# %%
# Elbow Method for K-Means
sse = []  # Sum of squared distances
k_range = range(1, 11)  # Possible values of k

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)  # Inertia: Sum of squared distances to closest cluster center

# Plotting the Elbow Method results
plt.figure(figsize=(8, 6))
plt.plot(k_range, sse, marker='o')
plt.title("Elbow Method for K-Means Clustering")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Sum of squared distances")
plt.xticks(k_range)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...
